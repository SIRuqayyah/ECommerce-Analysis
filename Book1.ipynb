# %%
import pandas as pd

pak = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")
# Out:
# C:\Users\Ruqayya\AppData\Local\Temp\ipykernel_3436\635093716.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   pak = pd.read_csv("Pakistan Largest Ecommerce Dataset.csv")

# %%
pak.head()
# Out:
#    item_id          status  created_at  \
# 0   211131        complete  07/01/2016
# 1   211133        canceled  07/01/2016
# 2   211134        canceled  07/01/2016
# 3   211135        complete  07/01/2016
# 4   211136  order_refunded  07/01/2016
#
#                                                  sku   price  qty_ordered  \
# 0                                  kreations_YI 06-L  1950.0            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...   240.0            1
# 2                                 Ego_UP0017-999-MR0  2450.0            1
# 3                                     kcc_krone deal   360.0            1
# 4                                        BK7010400AG   555.0            2
#
#    grand_total increment_id    category_name_1 sales_commission_code  ...  \
# 0       1950.0    100147443    Women's Fashion                    \N  ...
# 1        240.0    100147444  Beauty & Grooming                    \N  ...
# ...

# %%
pak.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID'],
#       dtype='object')

# %%
pak2 = pak.iloc[:5000]

# %%
pak2.describe()
# Out:
#              item_id          price  qty_ordered   grand_total  \
# count    5000.000000    5000.000000  5000.000000  5.000000e+03
# mean   213967.915200    3007.213270     1.143400  4.249849e+03
# std      1625.316109   11110.080269     0.955102  2.096757e+04
# min    211131.000000       0.150000     1.000000  0.000000e+00
# 25%    212574.750000     240.000000     1.000000  3.200000e+02
# 50%    213996.500000     425.000000     1.000000  7.800000e+02
# 75%    215368.250000    1101.500000     1.000000  1.998000e+03
# max    216774.000000  190725.000000    34.000000  1.155966e+06
#
#        discount_amount    Year   Month  Customer ID
# count      5000.000000  5000.0  5000.0   5000.00000
# mean         11.568198  2016.0     7.0    594.38900
# std          98.415329     0.0     0.0    470.18417
# min           0.000000  2016.0     7.0      1.00000
# 25%           0.000000  2016.0     7.0    143.00000
# 50%           0.000000  2016.0     7.0    527.50000
# ...

# %%
pak2.to_csv('Pakistan_Market.csv', index=False, header=True)
